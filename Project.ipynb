# %%
In [1]:
import pandas as pd
import seaborn as sns
In [2]:
# 1. Read the dataset
data = pd.read_csv("pubg - Dr. Darshan Ingle.csv")
data
Out[2]:
Id	groupId	matchId	assists	boosts	damageDealt	DBNOs	headshotKills	heals	killPlace	...	revives	rideDistance	roadKills	swimDistance	teamKills	vehicleDestroys	walkDistance	weaponsAcquired	winPoints	winPlacePerc
0	2f262dd9795e60	78437bcd91d40e	d5db3a49eb2955	0	0	0.0	0	0	0	92	...	0	0.0	0	0.0	0	0	0.00	0	1470	0.0000
1	a32847cf5bf34b	85b7ce5a12e10b	65223f05c7fdb4	0	0	163.2	1	1	0	42	...	0	0.0	0	0.0	0	0	132.70	2	1531	0.2222
2	1b1900a9990396	edf80d6523380a	1cadec4534f30a	0	3	278.7	2	1	8	16	...	3	0.0	0	0.0	0	0	3591.00	10	0	0.8571
3	f589dd03b60bf2	804ab5e5585558	c4a5676dc91604	0	0	191.9	1	0	0	31	...	0	0.0	0	0.0	0	0	332.70	3	0	0.3462
4	c23c4cc5b78b35	b3e2cd169ed920	cd595700a01bfa	0	0	100.0	1	0	0	87	...	0	0.0	0	0.0	0	0	252.70	3	1557	0.0690
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
9995	ef4f474acd8e85	2eca2a8391f75d	492ecdfae90b46	0	3	204.5	1	0	0	17	...	3	0.0	0	0.0	0	0	1648.00	4	1471	0.8333
9996	cf0bf82fb4d80e	2eaf2765f93adb	14bffd71e96320	0	0	0.0	0	0	0	49	...	0	0.0	0	0.0	0	0	897.10	6	1500	0.7174
9997	a0a31a0b1dcbe1	8d50c64ccc5071	147e4bbb62e3bb	0	0	0.0	0	0	0	83	...	0	0.0	0	0.0	0	0	188.20	2	1434	0.2083
9998	f6874657399d69	d31843d7e62ccb	662567dcf280f5	0	0	0.0	0	0	0	82	...	0	0.0	0	0.0	0	0	108.10	5	1534	0.2449
9999	90359b0b8f8b0d	61d5b1bb8da43f	258bfa48d88014	0	0	0.0	0	0	0	78	...	0	0.0	0	0.0	0	0	53.36	1	0	0.1875
10000 rows × 29 columns

In [3]:
# 2. Check the datatype of all the columns
data.dtypes
Out[3]:
Id                  object
groupId             object
matchId             object
assists              int64
boosts               int64
damageDealt        float64
DBNOs                int64
headshotKills        int64
heals                int64
killPlace            int64
killPoints           int64
kills                int64
killStreaks          int64
longestKill        float64
matchDuration        int64
matchType           object
maxPlace             int64
numGroups            int64
rankPoints           int64
revives              int64
rideDistance       float64
roadKills            int64
swimDistance       float64
teamKills            int64
vehicleDestroys      int64
walkDistance       float64
weaponsAcquired      int64
winPoints            int64
winPlacePerc       float64
dtype: object
In [4]:
# 3. Find the summary of all the numerical columns
data.describe()
Out[4]:
assists	boosts	damageDealt	DBNOs	headshotKills	heals	killPlace	killPoints	kills	killStreaks	...	revives	rideDistance	roadKills	swimDistance	teamKills	vehicleDestroys	walkDistance	weaponsAcquired	winPoints	winPlacePerc
count	10000.000000	10000.000000	10000.000000	10000.00000	10000.000000	10000.000000	10000.000000	10000.000000	10000.000000	10000.000000	...	10000.000000	10000.000000	10000.000000	10000.000000	10000.000000	10000.000000	10000.000000	10000.00000	10000.0000	10000.000000
mean	0.234600	1.088500	129.211264	0.64400	0.221700	1.354000	47.663100	506.970200	0.913400	0.543800	...	0.160200	600.693584	0.004200	4.385917	0.024400	0.007700	1130.008410	3.63590	609.3440	0.469926
std	0.575149	1.703279	167.193945	1.09562	0.577046	2.629102	27.424146	627.297959	1.524117	0.701948	...	0.454045	1524.915601	0.074719	30.889620	0.171486	0.089674	1168.597983	2.42209	739.7924	0.304508
min	0.000000	0.000000	0.000000	0.00000	0.000000	0.000000	1.000000	0.000000	0.000000	0.000000	...	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	0.00000	0.0000	0.000000
25%	0.000000	0.000000	0.000000	0.00000	0.000000	0.000000	24.000000	0.000000	0.000000	0.000000	...	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	151.575000	2.00000	0.0000	0.200000
50%	0.000000	0.000000	83.805000	0.00000	0.000000	0.000000	48.000000	0.000000	0.000000	0.000000	...	0.000000	0.000000	0.000000	0.000000	0.000000	0.000000	650.350000	3.00000	0.0000	0.458300
75%	0.000000	2.000000	185.325000	1.00000	0.000000	2.000000	71.000000	1169.000000	1.000000	1.000000	...	0.000000	0.000575	0.000000	0.000000	0.000000	0.000000	1923.250000	5.00000	1495.0000	0.735100
max	7.000000	18.000000	3469.000000	11.00000	14.000000	31.000000	100.000000	1926.000000	35.000000	4.000000	...	5.000000	28780.000000	3.000000	971.200000	3.000000	2.000000	10490.000000	41.00000	1863.0000	1.000000
8 rows × 25 columns

In [5]:
# 4. The average person kills how many players?
data['kills'].mean()
Out[5]:
0.9134
In [6]:
# 5. 99% of people have how many kills?
data['kills'].quantile(.99)
Out[6]:
7.0
In [7]:
# 6. The most kills ever recorded are how much?
data['kills'].max()
Out[7]:
35
In [8]:
# 7. Print all the columns of the dataframe
data.columns
Out[8]:
Index(['Id', 'groupId', 'matchId', 'assists', 'boosts', 'damageDealt', 'DBNOs',
       'headshotKills', 'heals', 'killPlace', 'killPoints', 'kills',
       'killStreaks', 'longestKill', 'matchDuration', 'matchType', 'maxPlace',
       'numGroups', 'rankPoints', 'revives', 'rideDistance', 'roadKills',
       'swimDistance', 'teamKills', 'vehicleDestroys', 'walkDistance',
       'weaponsAcquired', 'winPoints', 'winPlacePerc'],
      dtype='object')
In [9]:
# 8. Distribution of the match's duration
sns.distplot( data['matchDuration'] );

From the above distribution plot it can be concluded that: Most of the match duration is between 1250 sec and 1500 sec and also between 1750 sec and 2000 sec
In [10]:
# 9. Distribution of the walk distance
sns.distplot( data['walkDistance'] );

From the above distribution plot it can be concluded that: most of the total distance traveled on foot is bewtween 0 to 2000 meters.
In [11]:
# 10. Plot distribution of the match's duration vs walk distance one below the other.
import matplotlib.pyplot as plt
plt.figure(figsize=(5,10))
plt.subplot(2,1,1)
sns.distplot(data['matchDuration'])
plt.subplot(2,1,2)
sns.distplot(data['walkDistance']);

In [12]:
# 11. Plot distribution of the match's duration vs walk distance side by side
plt.figure(figsize=(15,3))
plt.subplot(1,2,1)
sns.distplot(data['matchDuration'])
plt.subplot(1,2,2)
sns.distplot(data['walkDistance']);

In [13]:
# 12. Pairplot the dataframe
sns.pairplot(data);

The kills vs damageDealt plot shows a linear relationship. More the no. of kills, more is the damage The maxPlace vs numGroups plot shows a straight line curve. Almost every group visits the same maximum number of places
In [14]:
# 13. How many unique values are there in 'matchType' and what are their counts?
data['matchType'].value_counts()
Out[14]:
squad-fpp           3969
duo-fpp             2282
squad               1359
solo-fpp            1234
duo                  702
solo                 386
normal-squad-fpp      24
crashfpp              13
normal-duo-fpp        13
normal-solo-fpp        8
normal-squad           4
flaretpp               3
crashtpp               2
flarefpp               1
Name: matchType, dtype: int64
In [26]:
# 14. Barplot of ‘matchType’ vs 'killPoints'
sns.barplot(x='killPoints', y='matchType', data=data);

The above graph shows what are the kill points for different match types
In [27]:
# 15. Barplot of ‘matchType’ vs ‘weaponsAcquired’
sns.barplot(x='weaponsAcquired', y='matchType', data=data);

The above graph shows the number of weapons picked up for a particular type of match
In [17]:
# 16. The Categorical columns
data.select_dtypes(include=['category'])
Out[17]:
0
1
2
3
4
...
9995
9996
9997
9998
9999
10000 rows × 0 columns

In [28]:
# 17. Boxplot of ‘matchType’ vs ‘winPlacePerc’
sns.boxplot(x='winPlacePerc', y='matchType', data=data);

The above graph shows the target of prediction for a particular type of match
In [30]:
# 18. Boxplot of ‘matchType’ vs ‘matchDuration’
sns.boxplot(x='matchDuration', y='matchType', data=data);

The above graph shows for how many duration a particular type of match is played
In [32]:
# 19. Change the orientation of the above plot to horizontal
sns.boxplot(x='matchType', y='matchDuration', data=data);
plt.xticks(rotation=70);

In [33]:
data['KILL'] = data['headshotKills']+data['teamKills']+data['roadKills']
data
Out[33]:
Id	groupId	matchId	assists	boosts	damageDealt	DBNOs	headshotKills	heals	killPlace	...	rideDistance	roadKills	swimDistance	teamKills	vehicleDestroys	walkDistance	weaponsAcquired	winPoints	winPlacePerc	KILL
0	2f262dd9795e60	78437bcd91d40e	d5db3a49eb2955	0	0	0.0	0	0	0	92	...	0.0	0	0.0	0	0	0.00	0	1470	0.0000	0
1	a32847cf5bf34b	85b7ce5a12e10b	65223f05c7fdb4	0	0	163.2	1	1	0	42	...	0.0	0	0.0	0	0	132.70	2	1531	0.2222	1
2	1b1900a9990396	edf80d6523380a	1cadec4534f30a	0	3	278.7	2	1	8	16	...	0.0	0	0.0	0	0	3591.00	10	0	0.8571	1
3	f589dd03b60bf2	804ab5e5585558	c4a5676dc91604	0	0	191.9	1	0	0	31	...	0.0	0	0.0	0	0	332.70	3	0	0.3462	0
4	c23c4cc5b78b35	b3e2cd169ed920	cd595700a01bfa	0	0	100.0	1	0	0	87	...	0.0	0	0.0	0	0	252.70	3	1557	0.0690	0
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
9995	ef4f474acd8e85	2eca2a8391f75d	492ecdfae90b46	0	3	204.5	1	0	0	17	...	0.0	0	0.0	0	0	1648.00	4	1471	0.8333	0
9996	cf0bf82fb4d80e	2eaf2765f93adb	14bffd71e96320	0	0	0.0	0	0	0	49	...	0.0	0	0.0	0	0	897.10	6	1500	0.7174	0
9997	a0a31a0b1dcbe1	8d50c64ccc5071	147e4bbb62e3bb	0	0	0.0	0	0	0	83	...	0.0	0	0.0	0	0	188.20	2	1434	0.2083	0
9998	f6874657399d69	d31843d7e62ccb	662567dcf280f5	0	0	0.0	0	0	0	82	...	0.0	0	0.0	0	0	108.10	5	1534	0.2449	0
9999	90359b0b8f8b0d	61d5b1bb8da43f	258bfa48d88014	0	0	0.0	0	0	0	78	...	0.0	0	0.0	0	0	53.36	1	0	0.1875	0
10000 rows × 30 columns

In [35]:
# 21. Round off column ‘winPlacePerc’ to 2 decimals
data['winPlacePerc'] = round( data['winPlacePerc'] , 2 )
data
Out[35]:
Id	groupId	matchId	assists	boosts	damageDealt	DBNOs	headshotKills	heals	killPlace	...	rideDistance	roadKills	swimDistance	teamKills	vehicleDestroys	walkDistance	weaponsAcquired	winPoints	winPlacePerc	KILL
0	2f262dd9795e60	78437bcd91d40e	d5db3a49eb2955	0	0	0.0	0	0	0	92	...	0.0	0	0.0	0	0	0.00	0	1470	0.00	0
1	a32847cf5bf34b	85b7ce5a12e10b	65223f05c7fdb4	0	0	163.2	1	1	0	42	...	0.0	0	0.0	0	0	132.70	2	1531	0.22	1
2	1b1900a9990396	edf80d6523380a	1cadec4534f30a	0	3	278.7	2	1	8	16	...	0.0	0	0.0	0	0	3591.00	10	0	0.86	1
3	f589dd03b60bf2	804ab5e5585558	c4a5676dc91604	0	0	191.9	1	0	0	31	...	0.0	0	0.0	0	0	332.70	3	0	0.35	0
4	c23c4cc5b78b35	b3e2cd169ed920	cd595700a01bfa	0	0	100.0	1	0	0	87	...	0.0	0	0.0	0	0	252.70	3	1557	0.07	0
...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...	...
9995	ef4f474acd8e85	2eca2a8391f75d	492ecdfae90b46	0	3	204.5	1	0	0	17	...	0.0	0	0.0	0	0	1648.00	4	1471	0.83	0
9996	cf0bf82fb4d80e	2eaf2765f93adb	14bffd71e96320	0	0	0.0	0	0	0	49	...	0.0	0	0.0	0	0	897.10	6	1500	0.72	0
9997	a0a31a0b1dcbe1	8d50c64ccc5071	147e4bbb62e3bb	0	0	0.0	0	0	0	83	...	0.0	0	0.0	0	0	188.20	2	1434	0.21	0
9998	f6874657399d69	d31843d7e62ccb	662567dcf280f5	0	0	0.0	0	0	0	82	...	0.0	0	0.0	0	0	108.10	5	1534	0.24	0
9999	90359b0b8f8b0d	61d5b1bb8da43f	258bfa48d88014	0	0	0.0	0	0	0	78	...	0.0	0	0.0	0	0	53.36	1	0	0.19	0
10000 rows × 30 columns

In [36]:
# 22. Take a sample of size 50 from the column damageDealt for 100 times and calculate its mean.
arr=[]
for i in range(100):
    arr.append(data['damageDealt'].sample(50).mean())
arr = pd.DataFrame(arr, columns=['damageDealt'])
arr
Out[36]:
damageDealt
0	132.53140
1	98.76436
2	121.02920
3	162.97920
4	120.58968
...	...
95	133.99617
96	147.73020
97	132.67880
98	183.24480
99	136.66220
100 rows × 1 columns

In [37]:
# Plot it on a histogram
sns.distplot(arr, kde=False);

From the above distribution plot it can be concluded that: total damage default is maximum between 100 to 160 in number
In [ ]:
